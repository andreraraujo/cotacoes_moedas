# %%
import pandas
from pandas_datareader import data as pdr
import yfinance as yfin
import matplotlib.pyplot as plt
yfin.pdr_override()
v = 0
print('Bem vindo(a) ao Cotações Mundiais!')
while v != 6:
  print("""Selecione a moeda para ver a cotação: 
        [1] USD/BRL
        [2] ARS/BRL
        [3] AUD/BRL
        [4] CAD/BRL
        [5] EUR/BRL
        [6] Encerrar programa
        """)
  v = int(input())
  if v == 1:
      print('USD/BRL')
      df = pdr.get_data_yahoo("USDBRL=X", start="2023-01-01")
      display(df)
      print('Gráfico da cotação USD/BRL em 2023')
      df["Adj Close"].plot(figsize=(6, 3))
      plt.show()
  if v == 2:
      print('ARS/BRL')
      df = pdr.get_data_yahoo("ARSBRL=X", start="2023-01-01")
      display(df)
      print('Gráfico da cotação ARS/BRL em 2023')
      df["Adj Close"].plot(figsize=(6, 3))
      plt.show()
  if v == 3:
      print('AUD/BRL')
      df = pdr.get_data_yahoo("AUDBRL=X", start="2023-01-01")
      print('Gráfico da cotação AUD/BRL em 2023')
      display(df)
      df["Adj Close"].plot(figsize=(6, 3))
      plt.show()
  if v == 4:
      print('CAD/BRL')
      df = pdr.get_data_yahoo("CADBRL=X", start="2023-01-01")
      print('Gráfico da cotação CAD/BRL em 2023')
      display(df)
      df["Adj Close"].plot(figsize=(6, 3))
      plt.show()
  if v == 5:
      print('EUR/BRL')
      df = pdr.get_data_yahoo("EURBRL=X", start="2023-01-01")
      display(df)
      print('Gráfico da cotação EUR/BRL em 2023')
      df["Adj Close"].plot(figsize=(6, 3))
      plt.show()
print('Programa encerrado')
# Out:
# Bem vindo(a) ao Cotações Mundiais!
# Selecione a moeda para ver a cotação:
#         [1] USD/BRL
#         [2] ARS/BRL
#         [3] AUD/BRL
#         [4] CAD/BRL
#         [5] EUR/BRL
#         [6] Encerrar programa
#
# 1
# USD/BRL
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2023-01-02  5.285500  5.362100  5.281984  5.285500   5.285500       0
# 2023-01-03  5.360131  5.422100  5.340700  5.360131   5.360131       0
# 2023-01-04  5.478500  5.479400  5.425700  5.478500   5.478500       0
# 2023-01-05  5.430100  5.431100  5.369500  5.430100   5.430100       0
# 2023-01-06  5.349800  5.360859  5.244500  5.349800   5.349800       0
# ...              ...       ...       ...       ...        ...     ...
# 2023-03-30  5.134200  5.155928  5.077300  5.134200   5.134200       0
# 2023-03-31  5.092700  5.103300  5.055200  5.092700   5.092700       0
# 2023-04-03  5.062300  5.075500  5.036216  5.062300   5.062300       0
# 2023-04-04  5.063100  5.097600  5.048277  5.063100   5.063100       0
# 2023-04-05  5.070700  5.074300  5.027504  5.070700   5.070700       0
#
# [68 rows x 6 columns]
# Gráfico da cotação USD/BRL em 2023
# Selecione a moeda para ver a cotação:
#         [1] USD/BRL
#         [2] ARS/BRL
#         [3] AUD/BRL
#         [4] CAD/BRL
#         [5] EUR/BRL
#         [6] Encerrar programa
#
# 5
# EUR/BRL
# [*********************100%***********************]  1 of 1 completed
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 2023-01-02  5.6189  5.7256  5.6189  5.6547     5.6547       0
# 2023-01-03  5.7213  5.7240  5.6269  5.7232     5.7232       0
# 2023-01-04  5.7746  5.8212  5.7515  5.7763     5.7763       0
# 2023-01-05  5.7550  5.7697  5.6513  5.7585     5.7585       0
# 2023-01-06  5.6275  5.6342  5.5488  5.6262     5.6262       0
# ...            ...     ...     ...     ...        ...     ...
# 2023-03-31  5.5523  5.5615  5.4891  5.5518     5.5518       0
# 2023-04-03  5.4616  5.5231  5.4603  5.4856     5.4856       0
# 2023-04-04  5.5189  5.5813  5.5023  5.5201     5.5201       0
# 2023-04-05  5.5543  5.5599  5.4953  5.5538     5.5538       0
# 2023-04-06  5.4900  5.5383  5.4814  5.5327     5.5327       0
#
# [69 rows x 6 columns]
# Gráfico da cotação EUR/BRL em 2023
# Selecione a moeda para ver a cotação:
#         [1] USD/BRL
#         [2] ARS/BRL
#         [3] AUD/BRL
#         [4] CAD/BRL
#         [5] EUR/BRL
#         [6] Encerrar programa
